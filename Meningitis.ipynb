# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %matplotlib inline
# Out:
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
al = pd.read_csv('./IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_STATES_A_TO_F_CSV/IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_ALABAMA_Y2018M03D27.CSV')

ak = pd.read_csv('IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_STATES_A_TO_F_CSV/IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_ALASKA_Y2018M03D27.CSV')

az = pd.read_csv('IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_STATES_A_TO_F_CSV/IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_ARIZONA_Y2018M03D27.CSV')

ar = pd.read_csv('IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_STATES_A_TO_F_CSV/IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_ARKANSAS_Y2018M03D27.CSV')

ca = pd.read_csv('IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_STATES_A_TO_F_CSV/IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_CALIFORNIA_Y2018M03D27.CSV')

co = pd.read_csv('IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_STATES_A_TO_F_CSV/IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_COLORADO_Y2018M03D27.CSV')

ct = pd.read_csv('IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_STATES_A_TO_F_CSV/IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_CONNECTICUT_Y2018M03D27.CSV')

de = pd.read_csv('IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_STATES_A_TO_F_CSV/IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_DELAWARE_Y2018M03D27.CSV')

dc = pd.read_csv('IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_STATES_A_TO_F_CSV/IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_DISTRICT_OF_COLUMBIA_Y2018M03D27.CSV')

fl = pd.read_csv('IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_STATES_A_TO_F_CSV/IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_FLORIDA_Y2018M03D27.CSV')

# %%
ga = pd.read_csv('IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_STATES_G_TO_L_CSV/IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_GEORGIA_Y2018M03D27.CSV')

hi = pd.read_csv('IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_STATES_G_TO_L_CSV/IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_HAWAII_Y2018M03D27.CSV')

id_ = pd.read_csv('IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_STATES_G_TO_L_CSV/IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_IDAHO_Y2018M03D27.CSV')

il = pd.read_csv('IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_STATES_G_TO_L_CSV/IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_ILLINOIS_Y2018M03D27.CSV')

in_ = pd.read_csv('IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_STATES_G_TO_L_CSV/IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_INDIANA_Y2018M03D27.CSV')

ia = pd.read_csv('IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_STATES_G_TO_L_CSV/IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_IOWA_Y2018M03D27.CSV')

ks = pd.read_csv('IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_STATES_G_TO_L_CSV/IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_KANSAS_Y2018M03D27.CSV')

ky = pd.read_csv('IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_STATES_G_TO_L_CSV/IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_KENTUCKY_Y2018M03D27.CSV')

la = pd.read_csv('IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_STATES_G_TO_L_CSV/IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_LOUISIANA_Y2018M03D27.CSV')

# %%
me = pd.read_csv('IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_STATES_M_TO_N_CSV/IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_MAINE_Y2018M03D27.CSV')
md = pd.read_csv('IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_STATES_M_TO_N_CSV/IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_MARYLAND_Y2018M03D27.CSV')
ma = pd.read_csv('IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_STATES_M_TO_N_CSV/IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_MASSACHUSETTS_Y2018M03D27.CSV')
mi = pd.read_csv('IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_STATES_M_TO_N_CSV/IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_MICHIGAN_Y2018M03D27.CSV')
mn = pd.read_csv('IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_STATES_M_TO_N_CSV/IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_MINNESOTA_Y2018M03D27.CSV')
ms = pd.read_csv('IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_STATES_M_TO_N_CSV/IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_MISSISSIPPI_Y2018M03D27.CSV')
mo = pd.read_csv('IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_STATES_M_TO_N_CSV/IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_MISSOURI_Y2018M03D27.CSV')
mt = pd.read_csv('IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_STATES_M_TO_N_CSV/IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_MONTANA_Y2018M03D27.CSV')
ne = pd.read_csv('IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_STATES_M_TO_N_CSV/IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_NEBRASKA_Y2018M03D27.CSV')
nv = pd.read_csv('IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_STATES_M_TO_N_CSV/IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_NEVADA_Y2018M03D27.CSV')
nh = pd.read_csv('IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_STATES_M_TO_N_CSV/IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_NEW_HAMPSHIRE_Y2018M03D27.CSV')
nj = pd.read_csv('IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_STATES_M_TO_N_CSV/IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_NEW_JERSEY_Y2018M03D27.CSV')
nm = pd.read_csv('IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_STATES_M_TO_N_CSV/IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_NEW_MEXICO_Y2018M03D27.CSV')
ny = pd.read_csv('IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_STATES_M_TO_N_CSV/IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_NEW_YORK_Y2018M03D27.CSV')
nc = pd.read_csv('IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_STATES_M_TO_N_CSV/IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_NORTH_CAROLINA_Y2018M03D27.CSV')
nd = pd.read_csv('IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_STATES_M_TO_N_CSV/IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_NORTH_DAKOTA_Y2018M03D27.CSV')

# %%
oh = pd.read_csv('IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_STATES_O_TO_S_CSV/IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_OHIO_Y2018M03D27.CSV')
ok = pd.read_csv('IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_STATES_O_TO_S_CSV/IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_OKLAHOMA_Y2018M03D27.CSV')
or_ = pd.read_csv('IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_STATES_O_TO_S_CSV/IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_OREGON_Y2018M03D27.CSV')
pa = pd.read_csv('IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_STATES_O_TO_S_CSV/IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_PENNSYLVANIA_Y2018M03D27.CSV')
ri = pd.read_csv('IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_STATES_O_TO_S_CSV/IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_RHODE_ISLAND_Y2018M03D27.CSV')
sc = pd.read_csv('IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_STATES_O_TO_S_CSV/IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_SOUTH_CAROLINA_Y2018M03D27.CSV')
sd = pd.read_csv('IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_STATES_O_TO_S_CSV/IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_SOUTH_DAKOTA_Y2018M03D27.CSV')

# %%
tn = pd.read_csv('IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_STATES_T_TO_W_CSV/IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_TENNESSEE_Y2018M03D27.CSV')
tx = pd.read_csv('IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_STATES_T_TO_W_CSV/IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_TEXAS_Y2018M03D27.CSV')
ut = pd.read_csv('IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_STATES_T_TO_W_CSV/IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_UTAH_Y2018M03D27.CSV')
vt = pd.read_csv('IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_STATES_T_TO_W_CSV/IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_VERMONT_Y2018M03D27.CSV')
va = pd.read_csv('IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_STATES_T_TO_W_CSV/IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_VIRGINIA_Y2018M03D27.CSV')
wa = pd.read_csv('IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_STATES_T_TO_W_CSV/IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_WASHINGTON_Y2018M03D27.CSV')
wv = pd.read_csv('IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_STATES_T_TO_W_CSV/IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_WEST_VIRGINIA_Y2018M03D27.CSV')
wi = pd.read_csv('IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_STATES_T_TO_W_CSV/IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_WISCONSIN_Y2018M03D27.CSV')
wy = pd.read_csv('IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_STATES_T_TO_W_CSV/IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_WYOMING_Y2018M03D27.CSV')

# %%
al = pd.DataFrame(al.loc[al['location_name'] == 'Alabama'])

al['new_index'] = range(al.shape[0])

al = al.set_index('new_index')

ak = pd.DataFrame(ak.loc[ak['location_name'] == 'Alaska'])

ak['new_index'] = range(630)

ak = ak.set_index('new_index')

az = pd.DataFrame(az.loc[az['location_name'] == 'Arizona'])

az['new_index'] = range(630)

az = az.set_index('new_index')

# %%
ar = pd.DataFrame(ar.loc[ar['location_name'] == 'Arkansas'])
ar['new_index'] = range(630)
ar = ar.set_index('new_index')

ca = pd.DataFrame(ca.loc[ca['location_name'] == 'California'])
ca['new_index'] = range(630)
ca = ca.set_index('new_index')

co = pd.DataFrame(co.loc[co['location_name'] == 'Colorado'])
co['new_index'] = range(630)
co = co.set_index('new_index')

ct = pd.DataFrame(ct.loc[ct['location_name'] == 'Connecticut'])
ct['new_index'] = range(630)
ct = ct.set_index('new_index')

de = pd.DataFrame(de.loc[de['location_name'] == 'Delaware'])
de['new_index'] = range(630)
de = de.set_index('new_index')

fl = pd.DataFrame(fl.loc[fl['location_name'] == 'Florida'])
fl['new_index'] = range(630)
fl = fl.set_index('new_index')

ga = pd.DataFrame(ga.loc[ga['location_name'] == 'Georgia'])
ga['new_index'] = range(630)
ga = ga.set_index('new_index')

hi = pd.DataFrame(hi.loc[hi['location_name'] == 'Hawaii'])
hi['new_index'] = range(630)
hi = hi.set_index('new_index')

id_ = pd.DataFrame(id_.loc[id_['location_name'] == 'Idaho'])
id_['new_index'] = range(630)
id_ = id_.set_index('new_index')

il = pd.DataFrame(il.loc[il['location_name'] == 'Illinois'])
il['new_index'] = range(630)
il = il.set_index('new_index')

in_ = pd.DataFrame(in_.loc[in_['location_name'] == 'Indiana'])
in_['new_index'] = range(630)
in_ = in_.set_index('new_index')

ia = pd.DataFrame(ia.loc[ia['location_name'] == 'Iowa'])
ia['new_index'] = range(630)
ia = ia.set_index('new_index')

ks = pd.DataFrame(ks.loc[ks['location_name'] == 'Kansas'])
ks['new_index'] = range(630)
ks = ks.set_index('new_index')

ky = pd.DataFrame(ky.loc[ky['location_name'] == 'Kentucky'])
ky['new_index'] = range(630)
ky = ky.set_index('new_index')

# %%
la = pd.DataFrame(la.loc[la['location_name'] == 'Louisiana'])
la['new_index'] = range(630)
la = la.set_index('new_index')

me = pd.DataFrame(me.loc[me['location_name'] == 'Maine'])
me['new_index'] = range(630)
me = me.set_index('new_index')

md = pd.DataFrame(md.loc[md['location_name'] == 'Maryland'])
md['new_index'] = range(630)
md = md.set_index('new_index')

ma = pd.DataFrame(ma.loc[ma['location_name'] == 'Massachusetts'])
ma['new_index'] = range(630)
ma = ma.set_index('new_index')

mi = pd.DataFrame(mi.loc[mi['location_name'] == 'Michigan'])
mi['new_index'] = range(630)
mi = mi.set_index('new_index')

mn = pd.DataFrame(mn.loc[mn['location_name'] == 'Minnesota'])
mn['new_index'] = range(630)
mn = mn.set_index('new_index')

ms = pd.DataFrame(ms.loc[ms['location_name'] == 'Mississippi'])
ms['new_index'] = range(630)
ms = ms.set_index('new_index')

mo = pd.DataFrame(mo.loc[mo['location_name'] == 'Missouri'])
mo['new_index'] = range(630)
mo = mo.set_index('new_index')

mt = pd.DataFrame(mt.loc[mt['location_name'] == 'Montana'])
mt['new_index'] = range(630)
mt = mt.set_index('new_index')

ne = pd.DataFrame(ne.loc[ne['location_name'] == 'Nebraska'])
ne['new_index'] = range(630)
ne = ne.set_index('new_index')

nv = pd.DataFrame(nv.loc[nv['location_name'] == 'Nevada'])
nv['new_index'] = range(630)
nv = nv.set_index('new_index')

nh = pd.DataFrame(nh.loc[nh['location_name'] == 'New Hampshire'])
nh['new_index'] = range(630)
nh = nh.set_index('new_index')

nj = pd.DataFrame(nj.loc[nj['location_name'] == 'New Jersey'])
nj['new_index'] = range(630)
nj = nj.set_index('new_index')

nm = pd.DataFrame(nm.loc[nm['location_name'] == 'New Mexico'])
nm['new_index'] = range(630)
nm = nm.set_index('new_index')

ny = pd.DataFrame(ny.loc[ny['location_name'] == 'New York'])
ny['new_index'] = range(630)
ny = ny.set_index('new_index')

nc = pd.DataFrame(nc.loc[nc['location_name'] == 'North Carolina'])
nc['new_index'] = range(630)
nc = nc.set_index('new_index')

# %%
nd = pd.DataFrame(nd.loc[nd['location_name'] == 'North Dakota'])
nd['new_index'] = range(630)
nd = nd.set_index('new_index')

oh = pd.DataFrame(oh.loc[oh['location_name'] == 'Ohio'])
oh['new_index'] = range(630)
oh = oh.set_index('new_index')

ok = pd.DataFrame(ok.loc[ok['location_name'] == 'Oklahoma'])
ok['new_index'] = range(630)
ok = ok.set_index('new_index')

or_ = pd.DataFrame(or_.loc[or_['location_name'] == 'Oregon'])
or_['new_index'] = range(630)
or_ = or_.set_index('new_index')

pa = pd.DataFrame(pa.loc[pa['location_name'] == 'Pennsylvania'])
pa['new_index'] = range(630)
pa = pa.set_index('new_index')

ri = pd.DataFrame(ri.loc[ri['location_name'] == 'Rhode Island'])
ri['new_index'] = range(630)
ri = ri.set_index('new_index')

sc = pd.DataFrame(sc.loc[sc['location_name'] == 'South Carolina'])
sc['new_index'] = range(630)
sc = sc.set_index('new_index')

sd = pd.DataFrame(sd.loc[sd['location_name'] == 'South Dakota'])
sd['new_index'] = range(630)
sd = sd.set_index('new_index')

tn = pd.DataFrame(tn.loc[tn['location_name'] == 'Tennessee'])
tn['new_index'] = range(630)
tn = tn.set_index('new_index')

tx = pd.DataFrame(tx.loc[tx['location_name'] == 'Texas'])
tx['new_index'] = range(630)
tx = tx.set_index('new_index')

ut = pd.DataFrame(ut.loc[ut['location_name'] == 'Utah'])
ut['new_index'] = range(630)
ut = ut.set_index('new_index')

vt = pd.DataFrame(vt.loc[vt['location_name'] == 'Vermont'])
vt['new_index'] = range(630)
vt = vt.set_index('new_index')

va = pd.DataFrame(va.loc[va['location_name'] == 'Virginia'])
va['new_index'] = range(630)
va = va.set_index('new_index')

wa = pd.DataFrame(wa.loc[wa['location_name'] == 'Washington'])
wa['new_index'] = range(630)
wa = wa.set_index('new_index')

wv = pd.DataFrame(wv.loc[wv['location_name'] == 'West Virginia'])
wv['new_index'] = range(630)
wv = wv.set_index('new_index')

wi = pd.DataFrame(wi.loc[wi['location_name'] == 'Wisconsin'])
wi['new_index'] = range(630)
wi = wi.set_index('new_index')

wy = pd.DataFrame(wy.loc[wy['location_name'] == 'Wyoming'])
wy['new_index'] = range(630)
wy = wy.set_index('new_index')

# %%
al.loc[(al['cause_name'] == 'Meningitis') & (al['sex'] == 'Both'), :]
# Out:
#            measure_id measure_name  location_id location_name  FIPS  cause_id  \
# new_index
# 490                 1       Deaths          523       Alabama     1       332
# 491                 1       Deaths          523       Alabama     1       332
# 492                 1       Deaths          523       Alabama     1       332
# 493                 1       Deaths          523       Alabama     1       332
# 494                 1       Deaths          523       Alabama     1       332
# 495                 1       Deaths          523       Alabama     1       332
# 496                 1       Deaths          523       Alabama     1       332
# 497                 1       Deaths          523       Alabama     1       332
# 498                 1       Deaths          523       Alabama     1       332
# 499                 1       Deaths          523       Alabama     1       332
# 500                 1       Deaths          523       Alabama     1       332
# ...

# %%
def t_meninpred(X, y):

    results = sm.GLM(y, sm.add_constant(X),
                sm.families.Gamma(sm.families.links.log)).fit()
    
    X_test = pd.DataFrame([2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022,
                           2023, 2024],
                      columns = ['future'])
    preds = []
    for i in range(10):
        preds.append(y[524] * np.exp(results.params[1]) ** (i + 1))
    print(results.params[1])
    return pd.concat([X_test, pd.DataFrame(preds)], axis = 1)

# %% [markdown]
# ## National Meningitis Trend

# %%
national = pd.read_csv('IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_STATES_T_TO_W_CSV/IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_UNITED_STATES_Y2018M03D27.CSV')

# %%
nat_t_menin = t_meninpred(national.loc[(national.index < 525) & (national.index > 489), :]['year_id'],
            national.loc[(national.index < 525) & (national.index > 489), :]['mx'])
nat_t_menin
# Out:
# -0.039065357335965264
#    future         0
# 0    2015  0.396881
# 1    2016  0.381675
# 2    2017  0.367052
# 3    2018  0.352990
# 4    2019  0.339466
# 5    2020  0.326460
# 6    2021  0.313953
# 7    2022  0.301925
# 8    2023  0.290357
# 9    2024  0.279233

# %%
import matplotlib

# %%
font = {'weight' : 'bold',
        'size'   : 28}

matplotlib.rc('font', **font)
plt.subplots(figsize = (16, 11))

plt.subplot(2, 2, 1)
plt.subplots_adjust(wspace = 0, hspace = 0)
plt.plot(national.loc[(national.index < 525) & (national.index > 489), :]['year_id'],
         national.loc[(national.index < 525) & (national.index > 489), :]['mx'], 'k')
plt.xlabel('Year', fontsize = 28)
plt.ylabel('Deaths / 100,000 pop.', fontsize = 28)
plt.title('National Mort. Rate', fontsize = 28)
plt.subplot(2, 2, 4)
plt.plot(nat_t_menin['future'], nat_t_menin[0], 'r')
plt.ylabel('Deaths / 100,000 pop.', fontsize = 28)
plt.xlabel('Year', fontsize = 28)
plt.title('National Mort. Pred.', fontsize = 28)
plt.suptitle('Meningitis', fontsize = 40)
# Out:
# Text(0.5,0.98,'Meningitis')

# %% [markdown]
# ## Assembling the 2019 Meningitis Data Frame

# %%
states = [al, ak, az, ar, ca, co, ct, de, fl, ga, hi, id_, il, in_, ia, ks, ky, la, me, md,
          ma, mi, mn, ms, mo, mt, ne, nv, nh, nj, nm, ny, nc, nd, oh, ok, or_, pa, ri, sc,
          sd, tn, tx, ut, vt, va, wa, wv, wi, wy]

# %%
for st in states:
    t_meninpred(st.loc[(st.index > 489) & (st.index < 525), :]['year_id'],
              st.loc[(st.index > 489) & (st.index < 525), :]['mx'])
# Out:
# -0.0321119031663137
#    future         0
# 0    2015  0.563968
# 1    2016  0.546146
# 2    2017  0.528887
# 3    2018  0.512173
# 4    2019  0.495987
# 5    2020  0.480313
# 6    2021  0.465135
# 7    2022  0.450436
# 8    2023  0.436201
# 9    2024  0.422416
# -0.042517981043139745
#    future         0
# 0    2015  0.413999
# 1    2016  0.396766
# 2    2017  0.380250
# 3    2018  0.364421
# 4    2019  0.349251
# 5    2020  0.334713
# 6    2021  0.320780
# 7    2022  0.307427
# 8    2023  0.294630
# 9    2024  0.282365
# -0.03645032689311352
#    future         0
# 0    2015  0.418967
# 1    2016  0.403971
# 2    2017  0.389511
# 3    2018  0.375569
# 4    2019  0.362126
# 5    2020  0.349164
# 6    2021  0.336666
# 7    2022  0.324615
# 8    2023  0.312996
# 9    2024  0.301793
# -0.03416906781081566
#    future         0
# 0    2015  0.502645
# 1    2016  0.485760
# 2    2017  0.469442
# 3    2018  0.453673
# 4    2019  0.438433
# 5    2020  0.423705
# 6    2021  0.409472
# ...

# %%
al_menin_df = t_meninpred(al.loc[(al.index > 489) & (al.index < 525), :]['year_id'],
                      al.loc[(al.index > 489) & (al.index < 525), :]['mx'])

al_menin = al_menin_df.loc[al_menin_df['future'] == 2019]

al_menin['state'] = 'Alabama'

al_menin['new_index'] = 0

al_menin.set_index('new_index', inplace = True)
# Out:
# -0.0321119031663137
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
ak_menin_df = t_meninpred(ak.loc[(ak.index > 489) & (ak.index < 525), :]['year_id'],
                      ak.loc[(ak.index > 489) & (ak.index < 525), :]['mx'])

ak_menin = ak_menin_df.loc[ak_menin_df['future'] == 2019]

ak_menin['state'] = 'Alaska'

ak_menin['new_index'] = 1

ak_menin.set_index('new_index', inplace = True)
# Out:
# -0.042517981043139745
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
az_menin_df = t_meninpred(az.loc[(az.index > 489) & (az.index < 525), :]['year_id'],
                      az.loc[(az.index > 489) & (az.index < 525), :]['mx'])

az_menin = az_menin_df.loc[az_menin_df['future'] == 2019]

az_menin['state'] = 'Arizona'

az_menin['new_index'] = 2

az_menin.set_index('new_index', inplace = True)
# Out:
# -0.03645032689311352
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
ar_menin_df = t_meninpred(ar.loc[(ar.index > 489) & (ar.index < 525), :]['year_id'],
                      ar.loc[(ar.index > 489) & (ar.index < 525), :]['mx'])

ar_menin = ar_menin_df.loc[ar_menin_df['future'] == 2019]

ar_menin['state'] = 'Arkansas'

ar_menin['new_index'] = 3

ar_menin.set_index('new_index', inplace = True)
# Out:
# -0.03416906781081566
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
ca_menin_df = t_meninpred(ca.loc[(ca.index > 489) & (ca.index < 525), :]['year_id'],
                      ca.loc[(ca.index > 489) & (ca.index < 525), :]['mx'])

ca_menin = ca_menin_df.loc[ca_menin_df['future'] == 2019]

ca_menin['state'] = 'California'

ca_menin['new_index'] = 4

ca_menin.set_index('new_index', inplace = True)
# Out:
# -0.0435232292950274
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
co_menin_df = t_meninpred(co.loc[(co.index > 489) & (co.index < 525), :]['year_id'],
                      co.loc[(co.index > 489) & (co.index < 525), :]['mx'])

co_menin = co_menin_df.loc[co_menin_df['future'] == 2019]

co_menin['state'] = 'Colorado'

co_menin['new_index'] = 5

co_menin.set_index('new_index', inplace = True)
# Out:
# -0.037058926855589015
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
ct_menin_df = t_meninpred(ct.loc[(ct.index > 489) & (ct.index < 525), :]['year_id'],
                      ct.loc[(ct.index > 489) & (ct.index < 525), :]['mx'])

ct_menin = ct_menin_df.loc[ct_menin_df['future'] == 2019]

ct_menin['state'] = 'Connecticut'

ct_menin['new_index'] = 6

ct_menin.set_index('new_index', inplace = True)
# Out:
# -0.04146619047599135
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
de_menin_df = t_meninpred(de.loc[(de.index > 489) & (de.index < 525), :]['year_id'],
                      de.loc[(de.index > 489) & (de.index < 525), :]['mx'])

de_menin = de_menin_df.loc[de_menin_df['future'] == 2019]

de_menin['state'] = 'Delaware'

de_menin['new_index'] = 7

de_menin.set_index('new_index', inplace = True)
# Out:
# -0.044097854070857576
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
fl_menin_df = t_meninpred(fl.loc[(fl.index > 489) & (fl.index < 525), :]['year_id'],
                      fl.loc[(fl.index > 489) & (fl.index < 525), :]['mx'])

fl_menin = fl_menin_df.loc[fl_menin_df['future'] == 2019]

fl_menin['state'] = 'Florida'

fl_menin['new_index'] = 8

fl_menin.set_index('new_index', inplace = True)
# Out:
# -0.04258417678153905
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
ga_menin_df = t_meninpred(ga.loc[(ga.index > 489) & (ga.index < 525), :]['year_id'],
                      ga.loc[(ga.index > 489) & (ga.index < 525), :]['mx'])

ga_menin = ga_menin_df.loc[ga_menin_df['future'] == 2019]

ga_menin['state'] = 'Georgia'

ga_menin['new_index'] = 9

ga_menin.set_index('new_index', inplace = True)
# Out:
# -0.03763898162935206
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
hi_menin_df = t_meninpred(hi.loc[(hi.index > 489) & (hi.index < 525), :]['year_id'],
                      hi.loc[(hi.index > 489) & (hi.index < 525), :]['mx'])

hi_menin = hi_menin_df.loc[hi_menin_df['future'] == 2019]

hi_menin['state'] = 'Hawaii'

hi_menin['new_index'] = 10

hi_menin.set_index('new_index', inplace = True)
# Out:
# -0.03601593791074193
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
id_menin_df = t_meninpred(id_.loc[(id_.index > 489) & (id_.index < 525), :]['year_id'],
                      id_.loc[(id_.index > 489) & (id_.index < 525), :]['mx'])

id_menin = id_menin_df.loc[id_menin_df['future'] == 2019]

id_menin['state'] = 'Idaho'

id_menin['new_index'] = 11

id_menin.set_index('new_index', inplace = True)
# Out:
# -0.03906807943561349
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
il_menin_df = t_meninpred(il.loc[(il.index > 489) & (il.index < 525), :]['year_id'],
                      il.loc[(il.index > 489) & (il.index < 525), :]['mx'])

il_menin = il_menin_df.loc[il_menin_df['future'] == 2019]

il_menin['state'] = 'Illinois'

il_menin['new_index'] = 12

il_menin.set_index('new_index', inplace = True)
# Out:
# -0.03538968457284378
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
in_menin_df = t_meninpred(in_.loc[(in_.index > 489) & (in_.index < 525), :]['year_id'],
                      in_.loc[(in_.index > 489) & (in_.index < 525), :]['mx'])

in_menin = in_menin_df.loc[in_menin_df['future'] == 2019]

in_menin['state'] = 'Indiana'

in_menin['new_index'] = 13

in_menin.set_index('new_index', inplace = True)
# Out:
# -0.03268481910518256
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
ia_menin_df = t_meninpred(ia.loc[(ia.index > 489) & (ia.index < 525), :]['year_id'],
                      ia.loc[(ia.index > 489) & (ia.index < 525), :]['mx'])

ia_menin = ia_menin_df.loc[ia_menin_df['future'] == 2019]

ia_menin['state'] = 'Iowa'

ia_menin['new_index'] = 14

ia_menin.set_index('new_index', inplace = True)
# Out:
# -0.03590387882031822
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
ks_menin_df = t_meninpred(ks.loc[(ks.index > 489) & (ks.index < 525), :]['year_id'],
                      ks.loc[(ks.index > 489) & (ks.index < 525), :]['mx'])

ks_menin = ks_menin_df.loc[ks_menin_df['future'] == 2019]

ks_menin['state'] = 'Kansas'

ks_menin['new_index'] = 15

ks_menin.set_index('new_index', inplace = True)
# Out:
# -0.031945930058806825
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
ky_menin_df = t_meninpred(ky.loc[(ky.index > 489) & (ky.index < 525), :]['year_id'],
                      ky.loc[(ky.index > 489) & (ky.index < 525), :]['mx'])

ky_menin = ky_menin_df.loc[ky_menin_df['future'] == 2019]

ky_menin['state'] = 'Kentucky'

ky_menin['new_index'] = 16

ky_menin.set_index('new_index', inplace = True)
# Out:
# -0.03242230620576288
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
la_menin_df = t_meninpred(la.loc[(la.index > 489) & (la.index < 525), :]['year_id'],
                      la.loc[(la.index > 489) & (la.index < 525), :]['mx'])

la_menin = la_menin_df.loc[la_menin_df['future'] == 2019]

la_menin['state'] = 'Louisiana'

la_menin['new_index'] = 17

la_menin.set_index('new_index', inplace = True)
# Out:
# -0.034433625354954665
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
me_menin_df = t_meninpred(me.loc[(me.index > 489) & (me.index < 525), :]['year_id'],
                      me.loc[(me.index > 489) & (me.index < 525), :]['mx'])

me_menin = me_menin_df.loc[me_menin_df['future'] == 2019]

me_menin['state'] = 'Maine'

me_menin['new_index'] = 18

me_menin.set_index('new_index', inplace = True)
# Out:
# -0.03854718469553767
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
md_menin_df = t_meninpred(md.loc[(md.index > 489) & (md.index < 525), :]['year_id'],
                      md.loc[(md.index > 489) & (md.index < 525), :]['mx'])

md_menin = md_menin_df.loc[md_menin_df['future'] == 2019]

md_menin['state'] = 'Maryland'

md_menin['new_index'] = 19

md_menin.set_index('new_index', inplace = True)
# Out:
# -0.04556278594346902
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
ma_menin_df = t_meninpred(ma.loc[(ma.index > 489) & (ma.index < 525), :]['year_id'],
                      ma.loc[(ma.index > 489) & (ma.index < 525), :]['mx'])

ma_menin = ma_menin_df.loc[ma_menin_df['future'] == 2019]

ma_menin['state'] = 'Massachusetts'

ma_menin['new_index'] = 20

ma_menin.set_index('new_index', inplace = True)
# Out:
# -0.042029129473643706
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
mi_menin_df = t_meninpred(mi.loc[(mi.index > 489) & (mi.index < 525), :]['year_id'],
                      mi.loc[(mi.index > 489) & (mi.index < 525), :]['mx'])

mi_menin = mi_menin_df.loc[mi_menin_df['future'] == 2019]

mi_menin['state'] = 'Michigan'

mi_menin['new_index'] = 21

mi_menin.set_index('new_index', inplace = True)
# Out:
# -0.03743528079677907
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
mn_menin_df = t_meninpred(mn.loc[(mn.index > 489) & (mn.index < 525), :]['year_id'],
                      mn.loc[(mn.index > 489) & (mn.index < 525), :]['mx'])

mn_menin = mn_menin_df.loc[mn_menin_df['future'] == 2019]

mn_menin['state'] = 'Minnesota'

mn_menin['new_index'] = 22

mn_menin.set_index('new_index', inplace = True)
# Out:
# -0.040812874476533735
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
ms_menin_df = t_meninpred(ms.loc[(ms.index > 489) & (ms.index < 525), :]['year_id'],
                      ms.loc[(ms.index > 489) & (ms.index < 525), :]['mx'])

ms_menin = ms_menin_df.loc[ms_menin_df['future'] == 2019]

ms_menin['state'] = 'Mississippi'

ms_menin['new_index'] = 23

ms_menin.set_index('new_index', inplace = True)
# Out:
# -0.03548508658181781
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
mo_menin_df = t_meninpred(mo.loc[(mo.index > 489) & (mo.index < 525), :]['year_id'],
                      mo.loc[(mo.index > 489) & (mo.index < 525), :]['mx'])

mo_menin = ak_menin_df.loc[ak_menin_df['future'] == 2019]

mo_menin['state'] = 'Missouri'

mo_menin['new_index'] = 24

mo_menin.set_index('new_index', inplace = True)
# Out:
# -0.03355856782394663
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
mt_menin_df = t_meninpred(mt.loc[(mt.index > 489) & (mt.index < 525), :]['year_id'],
                      mt.loc[(mt.index > 489) & (mt.index < 525), :]['mx'])

mt_menin = mt_menin_df.loc[mt_menin_df['future'] == 2019]

mt_menin['state'] = 'Montana'

mt_menin['new_index'] = 25

mt_menin.set_index('new_index', inplace = True)
# Out:
# -0.03850244117462285
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
ne_menin_df = t_meninpred(ne.loc[(ne.index > 489) & (ne.index < 525), :]['year_id'],
                      ne.loc[(ne.index > 489) & (ne.index < 525), :]['mx'])

ne_menin = ne_menin_df.loc[ne_menin_df['future'] == 2019]

ne_menin['state'] = 'Nebraska'

ne_menin['new_index'] = 26

ne_menin.set_index('new_index', inplace = True)
# Out:
# -0.03632842370703837
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
nv_menin_df = t_meninpred(nv.loc[(nv.index > 489) & (nv.index < 525), :]['year_id'],
                      nv.loc[(nv.index > 489) & (nv.index < 525), :]['mx'])

nv_menin = nv_menin_df.loc[nv_menin_df['future'] == 2019]

nv_menin['state'] = 'Nevada'

nv_menin['new_index'] = 27

nv_menin.set_index('new_index', inplace = True)
# Out:
# -0.03066678232217978
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
nh_menin_df = t_meninpred(nh.loc[(nh.index > 489) & (nh.index < 525), :]['year_id'],
                      nh.loc[(nh.index > 489) & (nh.index < 525), :]['mx'])

nh_menin = nh_menin_df.loc[nh_menin_df['future'] == 2019]

nh_menin['state'] = 'New Hampshire'

nh_menin['new_index'] = 28

nh_menin.set_index('new_index', inplace = True)
# Out:
# -0.04323568611064946
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
nj_menin_df = t_meninpred(nj.loc[(nj.index > 489) & (nj.index < 525), :]['year_id'],
                      nj.loc[(nj.index > 489) & (nj.index < 525), :]['mx'])

nj_menin = nj_menin_df.loc[nj_menin_df['future'] == 2019]

nj_menin['state'] = 'New Jersey'

nj_menin['new_index'] = 29

nj_menin.set_index('new_index', inplace = True)
# Out:
# -0.04554963303451778
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
nm_menin_df = t_meninpred(nm.loc[(nm.index > 489) & (nm.index < 525), :]['year_id'],
                      nm.loc[(nm.index > 489) & (nm.index < 525), :]['mx'])

nm_menin = nm_menin_df.loc[nm_menin_df['future'] == 2019]

nm_menin['state'] = 'New Mexico'

nm_menin['new_index'] = 30

nm_menin.set_index('new_index', inplace = True)
# Out:
# -0.03158517478190169
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
ny_menin_df = t_meninpred(ny.loc[(ny.index > 489) & (ny.index < 525), :]['year_id'],
                      ny.loc[(ny.index > 489) & (ny.index < 525), :]['mx'])

ny_menin = ny_menin_df.loc[ny_menin_df['future'] == 2019]

ny_menin['state'] = 'New York'

ny_menin['new_index'] = 31

ny_menin.set_index('new_index', inplace = True)
# Out:
# -0.04465764156760034
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
nc_menin_df = t_meninpred(nc.loc[(nc.index > 489) & (nc.index < 525), :]['year_id'],
                      nc.loc[(nc.index > 489) & (nc.index < 525), :]['mx'])

nc_menin = nc_menin_df.loc[nc_menin_df['future'] == 2019]

nc_menin['state'] = 'North Carolina'

nc_menin['new_index'] = 32

nc_menin.set_index('new_index', inplace = True)
# Out:
# -0.03964193599247443
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
nd_menin_df = t_meninpred(nd.loc[(nd.index > 489) & (nd.index < 525), :]['year_id'],
                      nd.loc[(nd.index > 489) & (nd.index < 525), :]['mx'])

nd_menin = nd_menin_df.loc[nd_menin_df['future'] == 2019]

nd_menin['state'] = 'North Dakota'

nd_menin['new_index'] = 33

nd_menin.set_index('new_index', inplace = True)
# Out:
# -0.03921272769121637
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
oh_menin_df = t_meninpred(oh.loc[(oh.index > 489) & (oh.index < 525), :]['year_id'],
                      oh.loc[(oh.index > 489) & (oh.index < 525), :]['mx'])

oh_menin = oh_menin_df.loc[oh_menin_df['future'] == 2019]

oh_menin['state'] = 'Ohio'

oh_menin['new_index'] = 34

oh_menin.set_index('new_index', inplace = True)
# Out:
# -0.03601144329032099
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
ok_menin_df = t_meninpred(ok.loc[(ok.index > 489) & (ok.index < 525), :]['year_id'],
                      ok.loc[(ok.index > 489) & (ok.index < 525), :]['mx'])

ok_menin = ok_menin_df.loc[ok_menin_df['future'] == 2019]

ok_menin['state'] = 'Oklahoma'

ok_menin['new_index'] = 35

ok_menin.set_index('new_index', inplace = True)
# Out:
# -0.0303387794281519
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
or_menin_df = t_meninpred(or_.loc[(or_.index > 489) & (or_.index < 525), :]['year_id'],
                      or_.loc[(or_.index > 489) & (or_.index < 525), :]['mx'])

or_menin = or_menin_df.loc[or_menin_df['future'] == 2019]

or_menin['state'] = 'Oregon'

or_menin['new_index'] = 36

or_menin.set_index('new_index', inplace = True)
# Out:
# -0.03740833037774007
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
pa_menin_df = t_meninpred(pa.loc[(pa.index > 489) & (pa.index < 525), :]['year_id'],
                      pa.loc[(pa.index > 489) & (pa.index < 525), :]['mx'])

pa_menin = pa_menin_df.loc[pa_menin_df['future'] == 2019]

pa_menin['state'] = 'Pennsylvania'

pa_menin['new_index'] = 37

pa_menin.set_index('new_index', inplace = True)
# Out:
# -0.04062727118946466
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
ri_menin_df = t_meninpred(ri.loc[(ri.index > 489) & (ri.index < 525), :]['year_id'],
                      ri.loc[(ri.index > 489) & (ri.index < 525), :]['mx'])

ri_menin = ri_menin_df.loc[ri_menin_df['future'] == 2019]

ri_menin['state'] = 'Rhode Island'

ri_menin['new_index'] = 38

ri_menin.set_index('new_index', inplace = True)
# Out:
# -0.03874505693916437
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
sc_menin_df = t_meninpred(sc.loc[(sc.index > 489) & (sc.index < 525), :]['year_id'],
                      sc.loc[(sc.index > 489) & (sc.index < 525), :]['mx'])

sc_menin = sc_menin_df.loc[sc_menin_df['future'] == 2019]

sc_menin['state'] = 'South Carolina'

sc_menin['new_index'] = 39

sc_menin.set_index('new_index', inplace = True)
# Out:
# -0.03863405055963085
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
sd_menin_df = t_meninpred(sd.loc[(sd.index > 489) & (sd.index < 525), :]['year_id'],
                      sd.loc[(sd.index > 489) & (sd.index < 525), :]['mx'])

sd_menin = sd_menin_df.loc[sd_menin_df['future'] == 2019]

sd_menin['state'] = 'South Dakota'

sd_menin['new_index'] = 40

sd_menin.set_index('new_index', inplace = True)
# Out:
# -0.03861158929846943
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
tn_menin_df = t_meninpred(tn.loc[(tn.index > 489) & (tn.index < 525), :]['year_id'],
                      tn.loc[(tn.index > 489) & (tn.index < 525), :]['mx'])

tn_menin = tn_menin_df.loc[tn_menin_df['future'] == 2019]

tn_menin['state'] = 'Tennessee'

tn_menin['new_index'] = 41

tn_menin.set_index('new_index', inplace = True)
# Out:
# -0.03358615962400946
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
tx_menin_df = t_meninpred(tx.loc[(tx.index > 489) & (tx.index < 525), :]['year_id'],
                      tx.loc[(tx.index > 489) & (tx.index < 525), :]['mx'])

tx_menin = tx_menin_df.loc[tx_menin_df['future'] == 2019]

tx_menin['state'] = 'Texas'

tx_menin['new_index'] = 42

tx_menin.set_index('new_index', inplace = True)
# Out:
# -0.0385167746635511
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
ut_menin_df = t_meninpred(ut.loc[(ut.index > 489) & (ut.index < 525), :]['year_id'],
                      ut.loc[(ut.index > 489) & (ut.index < 525), :]['mx'])

ut_menin = ut_menin_df.loc[ut_menin_df['future'] == 2019]

ut_menin['state'] = 'Utah'

ut_menin['new_index'] = 43

ut_menin.set_index('new_index', inplace = True)
# Out:
# -0.034214064100909054
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
vt_menin_df = t_meninpred(vt.loc[(vt.index > 489) & (vt.index < 525), :]['year_id'],
                      vt.loc[(vt.index > 489) & (vt.index < 525), :]['mx'])

vt_menin = vt_menin_df.loc[vt_menin_df['future'] == 2019]

vt_menin['state'] = 'Vermont'

vt_menin['new_index'] = 44

vt_menin.set_index('new_index', inplace = True)
# Out:
# -0.044212267963256675
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
va_menin_df = t_meninpred(va.loc[(va.index > 489) & (va.index < 525), :]['year_id'],
                      va.loc[(va.index > 489) & (va.index < 525), :]['mx'])

va_menin = va_menin_df.loc[va_menin_df['future'] == 2019]

va_menin['state'] = 'Virginia'

va_menin['new_index'] = 45

va_menin.set_index('new_index', inplace = True)
# Out:
# -0.04241105584509173
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
wa_menin_df = t_meninpred(wa.loc[(wa.index > 489) & (wa.index < 525), :]['year_id'],
                      wa.loc[(wa.index > 489) & (wa.index < 525), :]['mx'])

wa_menin = wa_menin_df.loc[wa_menin_df['future'] == 2019]

wa_menin['state'] = 'Washington'

wa_menin['new_index'] = 46

wa_menin.set_index('new_index', inplace = True)
# Out:
# -0.038066759693004056
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
wv_menin_df = t_meninpred(wv.loc[(wv.index > 489) & (wv.index < 525), :]['year_id'],
                      wv.loc[(wv.index > 489) & (wv.index < 525), :]['mx'])

wv_menin = wv_menin_df.loc[wv_menin_df['future'] == 2019]

wv_menin['state'] = 'West Virginia'

wv_menin['new_index'] = 47

wv_menin.set_index('new_index', inplace = True)
# Out:
# -0.033782381752249256
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
wi_menin_df = t_meninpred(wi.loc[(wi.index > 489) & (wi.index < 525), :]['year_id'],
                      wi.loc[(wi.index > 489) & (wi.index < 525), :]['mx'])

wi_menin = wi_menin_df.loc[wi_menin_df['future'] == 2019]

wi_menin['state'] = 'Wisconsin'

wi_menin['new_index'] = 48

wi_menin.set_index('new_index', inplace = True)
# Out:
# -0.03775740810327973
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
wy_menin_df = t_meninpred(wy.loc[(wy.index > 489) & (wy.index < 525), :]['year_id'],
                      wy.loc[(wy.index > 489) & (wy.index < 525), :]['mx'])

wy_menin = wy_menin_df.loc[wy_menin_df['future'] == 2019]

wy_menin['state'] = 'Wyoming'

wy_menin['new_index'] = 49

wy_menin.set_index('new_index', inplace = True)
# Out:
# -0.03531604674747984
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/gadamico/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
state_menin = pd.concat([al_menin, ak_menin, az_menin, ar_menin, ca_menin, co_menin, ct_menin,
                        de_menin, fl_menin, ga_menin, hi_menin, id_menin, il_menin, in_menin,
                        ia_menin, ks_menin, ky_menin, la_menin, me_menin, md_menin, ma_menin,
                        mi_menin, mn_menin, ms_menin, mo_menin, mt_menin, ne_menin, nv_menin,
                        nh_menin, nj_menin, nm_menin, ny_menin, nc_menin, nd_menin, oh_menin,
                        ok_menin, or_menin, pa_menin, ri_menin, sc_menin, sd_menin, tn_menin,
                        tx_menin, ut_menin, vt_menin, va_menin, wa_menin, wv_menin, wi_menin,
                        wy_menin])

# %%
state_menin.to_csv('state_menin.csv')
state_menin.loc[state_menin[0] == max(state_menin[0]), :]
# Out:
#            future         0      state
# new_index
# 17           2019  0.556351  Louisiana

# %%
state_menin.loc[state_menin[0] == min(state_menin[0]), :]
# Out:
#            future         0          state
# new_index
# 28           2019  0.221284  New Hampshire

# %% [markdown]
# ## Exploring Louisiana

# %%
louisiana = pd.read_csv('IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_STATES_G_TO_L_CSV/IHME_USA_COUNTY_INFECT_DIS_MORT_1980_2014_LOUISIANA_Y2018M03D27.CSV')

louisiana = louisiana.loc[(louisiana['cause_name'] == 'Meningitis') & (louisiana['location_name'] != 'Louisiana'), :]

louisiana = louisiana.drop(columns = ['measure_id', 'measure_name', 'location_id', 'FIPS',
                                'cause_id', 'cause_name', 'sex_id', 'age_id', 'age_name',
                                'metric'])

louisiana['location_name'].value_counts()
# Out:
# Saint Bernard Parish             105
# Webster Parish                   105
# Saint James Parish               105
# Madison Parish                   105
# Winn Parish                      105
# Caddo Parish                     105
# Saint Landry Parish              105
# West Baton Rouge Parish          105
# West Carroll Parish              105
# Sabine Parish                    105
# Livingston Parish                105
# Concordia Parish                 105
# Saint Mary Parish                105
# Terrebonne Parish                105
# Jefferson Davis Parish           105
# West Feliciana Parish            105
# Jefferson Parish                 105
# Assumption Parish                105
# Grant Parish                     105
# Natchitoches Parish              105
# Beauregard Parish                105
# Washington Parish                105
# Plaquemines Parish               105
# Ascension Parish                 105
# Claiborne Parish                 105
# ...

# %% [markdown]
# ### Climate Data

# %% [markdown]
# Louisiana climate data from https://commons.wikimedia.org/wiki/File:Louisiana_K%C3%B6ppen.png

# %%
louisiana['Climate'] = 'Humid subtropical'

# %% [markdown]
# Once again: not too interesting, but included here for completeness' sake.

# %% [markdown]
# ### Population Data

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.louisiana-demographics.com/counties_by_population'

# %%
requests.get(url).status_code
# Out:
# 200

# %%
soup = BeautifulSoup(requests.get(url).content, 'lxml')

headers = []
table = soup.find('table')

for th in table.findChildren('th'):
    headers.append(th.text)

# %%
headers
# Out:
# ['Rank', 'County', 'Population']

# %%
populations = []
table = soup.find('table')

for td in table.findChildren('td'):
    populations.append(td.text)

# %%
populations
# Out:
# ['\n        1\n      ',
#  '\nEast Baton Rouge Parish\n',
#  '\n        446,268\n\n      ',
#  '\n        2\n      ',
#  '\nJefferson Parish\n',
#  '\n        439,036\n\n      ',
#  '\n        3\n      ',
#  '\nOrleans Parish\n',
#  '\n        393,292\n\n      ',
#  '\n        4\n      ',
#  '\nSt. Tammany Parish\n',
#  '\n        256,327\n\n      ',
#  '\n        5\n      ',
#  '\nCaddo Parish\n',
#  '\n        246,581\n\n      ',
#  '\n        6\n      ',
#  '\nLafayette Parish\n',
#  '\n        242,485\n\n      ',
#  '\n        7\n      ',
#  '\nCalcasieu Parish\n',
#  '\n        202,445\n\n      ',
#  '\n        8\n      ',
#  '\nOuachita Parish\n',
#  '\n        155,874\n\n      ',
#  '\n        9\n      ',
#  '\nLivingston Parish\n',
#  '\n        138,228\n\n      ',
#  '\n        10\n      ',
#  '\nTangipahoa Parish\n',
#  '\n        132,497\n\n      ',
#  '\n        11\n      ',
#  '\nRapides Parish\n',
#  '\n        131,648\n\n      ',
#  '\n        12\n      ',
# ...

# %%
populations = [county.replace('\n', '') for county in populations]
populations = [county.replace(' ', '') for county in populations]
populations
# Out:
# ['1',
#  'EastBatonRougeParish',
#  '446,268',
#  '2',
#  'JeffersonParish',
#  '439,036',
#  '3',
#  'OrleansParish',
#  '393,292',
#  '4',
#  'St.TammanyParish',
#  '256,327',
#  '5',
#  'CaddoParish',
#  '246,581',
#  '6',
#  'LafayetteParish',
#  '242,485',
#  '7',
#  'CalcasieuParish',
#  '202,445',
#  '8',
#  'OuachitaParish',
#  '155,874',
#  '9',
#  'LivingstonParish',
#  '138,228',
#  '10',
#  'TangipahoaParish',
#  '132,497',
#  '11',
#  'RapidesParish',
#  '131,648',
#  '12',
#  'BossierParish',
#  '127,634',
#  '13',
#  'AscensionParish',
#  '122,948',
#  '14',
#  'TerrebonneParish',
#  '112,086',
#  '15',
#  'LafourcheParish',
#  '98,426',
#  '16',
#  'St.LandryParish',
#  '83,497',
#  '17',
#  'IberiaParish',
#  '72,176',
#  '18',
#  'AcadiaParish',
#  '62,590',
#  '19',
#  'VermilionParish',
#  '60,136',
#  '20',
#  'St.MartinParish',
#  '54,171',
#  '21',
#  'St.CharlesParish',
#  '52,749',
#  '22',
#  'St.MaryParish',
#  '50,973',
#  '23',
#  'VernonParish',
# ...

# %%
populations = populations[:-1]

# %%
peopledf = pd.DataFrame(np.reshape(populations, (64, 3)), columns = headers)
peopledf
# Out:
#    Rank                   County Population
# 0     1     EastBatonRougeParish    446,268
# 1     2          JeffersonParish    439,036
# 2     3            OrleansParish    393,292
# 3     4         St.TammanyParish    256,327
# 4     5              CaddoParish    246,581
# 5     6          LafayetteParish    242,485
# 6     7          CalcasieuParish    202,445
# 7     8           OuachitaParish    155,874
# 8     9         LivingstonParish    138,228
# 9    10         TangipahoaParish    132,497
# 10   11            RapidesParish    131,648
# 11   12            BossierParish    127,634
# 12   13          AscensionParish    122,948
# 13   14         TerrebonneParish    112,086
# 14   15          LafourcheParish     98,426
# 15   16          St.LandryParish     83,497
# 16   17             IberiaParish     72,176
# 17   18             AcadiaParish     62,590
# 18   19          VermilionParish     60,136
# 19   20          St.MartinParish     54,171
# ...

# %%
louisiana['location_name'].value_counts()
# Out:
# Saint Bernard Parish             105
# Webster Parish                   105
# Saint James Parish               105
# Madison Parish                   105
# Winn Parish                      105
# Caddo Parish                     105
# Saint Landry Parish              105
# West Baton Rouge Parish          105
# West Carroll Parish              105
# Sabine Parish                    105
# Livingston Parish                105
# Concordia Parish                 105
# Saint Mary Parish                105
# Terrebonne Parish                105
# Jefferson Davis Parish           105
# West Feliciana Parish            105
# Jefferson Parish                 105
# Assumption Parish                105
# Grant Parish                     105
# Natchitoches Parish              105
# Beauregard Parish                105
# Washington Parish                105
# Plaquemines Parish               105
# Ascension Parish                 105
# Claiborne Parish                 105
# ...

# %%
parishes = [parish.replace(' ', '') for parish in louisiana['location_name']]
parishes = [parish.replace('Saint', 'St.') for parish in parishes]
louisiana['location_name'] = parishes

# %%
louisiana_pop = pd.merge(louisiana, peopledf, how = 'left', left_on = 'location_name',
                        right_on = 'County')

# %% [markdown]
# ### Economic Data

# %%
url2 = 'https://en.wikipedia.org/wiki/List_of_Louisiana_locations_by_per_capita_income'
requests.get(url2).status_code
# Out:
# 200

# %%
soup = BeautifulSoup(requests.get(url2).content, 'lxml')

headers = []
table = soup.findAll('table')[2]

for th in table.findChildren('th'):
    headers.append(th.text)

# %%
headers
# Out:
# ['Rank',
#  'Parish',
#  'Per capita\nincome',
#  'Median\nhousehold\nincome',
#  'Median\nfamily\nincome',
#  'Population',
#  'Number of\nhouseholds']

# %%
headers = [header.replace('\n', ' ') for header in headers]

# %%
la_monies = []
table = soup.findAll('table')[2]

for td in table.findChildren('td'):
    la_monies.append(td.text)

# %%
la_moniesdf = pd.DataFrame(np.reshape(la_monies, (66, 7)), columns = headers)

# %%
la_moniesdf
# Out:
#    Rank                Parish Per capita income Median household income  \
# 0     1           St. Tammany           $22,514                 $60,866
# 1               United States           $27,334                 $51,914
# 2     2             Ascension           $26,888                 $63,716
# 3     3              La Salle           $26,791                 $47,559
# 4     4      East Baton Rouge           $26,260                 $46,179
# 5     5             Jefferson           $25,842                 $48,175
# 6     6           St. Charles           $25,728                 $60,961
# 7     7               Bossier           $25,630                 $51,020
# 8     8               Orleans           $24,929                 $37,468
# 9     9               Cameron           $24,634                 $59,555
# 10   10             Calcasieu           $23,591                 $43,758
# 11   11           Plaquemines           $23,378                 $54,730
# ...

# %%
zeroes = la_moniesdf.loc[la_moniesdf['Rank'] == '']

la_moniesdf = la_moniesdf.drop(zeroes.index)

la_moniesdf = la_moniesdf.reset_index()

la_moniesdf = la_moniesdf.drop(['index', 'Population'], axis = 1)

# %%
louisiana_pop.head()
# Out:
#   location_name   sex  year_id        mx     lower     upper  \
# 0  AcadiaParish  Male     1980  1.898836  1.568840  2.251647
# 1  AcadiaParish  Male     1981  1.893132  1.562790  2.231150
# 2  AcadiaParish  Male     1982  1.832998  1.514918  2.147315
# 3  AcadiaParish  Male     1983  1.857035  1.515865  2.195849
# 4  AcadiaParish  Male     1984  1.779557  1.462023  2.100735
#
#              Climate Rank        County Population
# 0  Humid subtropical   18  AcadiaParish     62,590
# 1  Humid subtropical   18  AcadiaParish     62,590
# 2  Humid subtropical   18  AcadiaParish     62,590
# 3  Humid subtropical   18  AcadiaParish     62,590
# 4  Humid subtropical   18  AcadiaParish     62,590

# %%
la_counties = [county.replace('Parish', '') for county in louisiana_pop['County']]

louisiana_pop['County'] = la_counties

# %%
counties = [county.replace(' ', '') for county in la_moniesdf['Parish']]

la_moniesdf['Parish'] = counties

# %%
set(la_moniesdf['Parish']) == set(louisiana_pop['County'])
# Out:
# True

# %%
louisiana_monies = pd.merge(louisiana_pop, la_moniesdf, how = 'left', left_on = 'County',
                           right_on = 'Parish')

# %%
louisiana_monies.head()
# Out:
#   location_name   sex  year_id        mx     lower     upper  \
# 0  AcadiaParish  Male     1980  1.898836  1.568840  2.251647
# 1  AcadiaParish  Male     1981  1.893132  1.562790  2.231150
# 2  AcadiaParish  Male     1982  1.832998  1.514918  2.147315
# 3  AcadiaParish  Male     1983  1.857035  1.515865  2.195849
# 4  AcadiaParish  Male     1984  1.779557  1.462023  2.100735
#
#              Climate Rank_x  County Population Rank_y  Parish  \
# 0  Humid subtropical     18  Acadia     62,590     48  Acadia
# 1  Humid subtropical     18  Acadia     62,590     48  Acadia
# 2  Humid subtropical     18  Acadia     62,590     48  Acadia
# 3  Humid subtropical     18  Acadia     62,590     48  Acadia
# 4  Humid subtropical     18  Acadia     62,590     48  Acadia
#
#   Per capita income Median household income Median family income  \
# 0           $18,116                 $37,261              $44,404
# 1           $18,116                 $37,261              $44,404
# ...

# %%
county_dums = pd.get_dummies(louisiana_monies['County'])
louisiana_monies = pd.concat([louisiana_monies, county_dums], axis = 1)

climate_dums = pd.get_dummies(louisiana_monies['Climate'])
louisiana_monies = pd.concat([louisiana_monies, climate_dums], axis = 1)

louisiana_monies.to_csv('louisiana_raw.csv')
